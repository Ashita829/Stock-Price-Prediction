# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashita829/Stock-Price-Prediction/blob/main/Stock_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Task 2: Stock Price Prediction

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load data
stock = yf.download("AAPL", start="2022-01-01", end="2024-01-01")

# Features & target
stock = stock[['Open', 'High', 'Low', 'Volume', 'Close']]
stock.dropna(inplace=True)

X = stock[['Open', 'High', 'Low', 'Volume']]
y = stock['Close']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)

# Plot
plt.figure(figsize=(10,5))
plt.plot(y_test.values, label="Actual")
plt.plot(predictions, label="Predicted")
plt.title("Stock Price Prediction (AAPL)")
plt.legend()
plt.show()
# Out:
# ...
# /tmp/ipykernel_742/3275204473.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock = yf.download("AAPL", start="2022-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed
